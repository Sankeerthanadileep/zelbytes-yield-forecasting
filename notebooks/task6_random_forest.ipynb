# %%
import pandas as pd

X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")
y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

print("X_train shape:", X_train.shape)
print("X_test shape :", X_test.shape)

print("\nColumns:")
print(X_train.columns.tolist())

print("\ny_train:")
print(y_train.head())
# Out:
# X_train shape: (80, 4)
# X_test shape : (20, 4)
#
# Columns:
# ['temperature', 'humidity', 'co2', 'temp_humidity']
#
# y_train:
#    yield_kg
# 0     12.34
# 1     12.55
# 2     13.60
# 3     13.49
# 4     12.98

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

print(y_pred[:5])
# Out:
# [13.6517 13.158  13.2807 12.8527 13.6784]

# %%
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(
    mean_squared_error(y_test, y_pred)
)

r2 = r2_score(y_test, y_pred)

print("MAE :", mae)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 0.8829800000000004
# RMSE: 1.0262915945285735
# R²  : -0.2964079740933687

# %%
import pandas as pd

importance_df = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": rf.feature_importances_
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df
# Out:
#          Feature  Importance
# 3  temp_humidity    0.319489
# 2            co2    0.282108
# 0    temperature    0.199860
# 1       humidity    0.198542

# %%
plt.figure(figsize=(8,5))

plt.bar(
    importance_df["Feature"],
    importance_df["Importance"]
)

plt.title("Random Forest Feature Importances")
plt.xlabel("Features")
plt.ylabel("Importance")

plt.tight_layout()

plt.savefig(
    "../reports/figures/rf_feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
train_pred = rf.predict(X_train)

# %%
train_mae = mean_absolute_error(
    y_train,
    train_pred
)

print("Train MAE:", train_mae)
print("Test MAE :", mae)
# Out:
# Train MAE: 0.20830124999999872
# Test MAE : 0.8829800000000004

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score

# %%
tscv = TimeSeriesSplit(n_splits=3)

print(tscv)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None)

# %%
rf_cv_scores = -cross_val_score(
    rf,
    X_train,
    y_train.values.ravel(),
    cv=tscv,
    scoring="neg_mean_absolute_error"
)

print("RF CV Scores:")
print(rf_cv_scores)

print("\nAverage RF CV MAE:")
print(rf_cv_scores.mean())
# Out:
# RF CV Scores:
# [0.644475 0.553115 0.55622 ]
#
# Average RF CV MAE:
# 0.5846033333333319

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr_cv_scores = -cross_val_score(
    lr,
    X_train,
    y_train.values.ravel(),
    cv=tscv,
    scoring="neg_mean_absolute_error"
)

print("LR CV Scores:")
print(lr_cv_scores)

print("\nAverage LR CV MAE:")
print(lr_cv_scores.mean())
# Out:
# LR CV Scores:
# [0.67035185 0.46657379 0.57305749]
#
# Average LR CV MAE:
# 0.5699943765611764

# %%
import joblib

joblib.dump(
    rf,
    "../models/random_forest.joblib"
)

print("Random Forest model saved.")
# Out:
# Random Forest model saved.

# %%
with open("../reports/cv_results.md", "w") as f:
    f.write("""# Cross Validation Results

## Methodology

TimeSeriesSplit with 3 folds was used to evaluate model performance while preserving chronological order and preventing data leakage.

## Random Forest Cross-Validation

- Fold 1 MAE: 0.644
- Fold 2 MAE: 0.553
- Fold 3 MAE: 0.556
- Average CV MAE: 0.585

## Linear Regression Cross-Validation

- Fold 1 MAE: 0.670
- Fold 2 MAE: 0.467
- Fold 3 MAE: 0.573
- Average CV MAE: 0.570

## Overfitting Analysis

- Train MAE: 0.208
- Test MAE: 0.883

The large gap between training and testing MAE indicates that the Random Forest model exhibits overfitting. The model learned the training data effectively but generalized less successfully to unseen data.

## Conclusion

Linear Regression achieved a slightly lower average CV MAE (0.570) than Random Forest (0.585), indicating marginally better predictive performance on this dataset. Random Forest provided useful feature importance insights but showed signs of overfitting.
""")
